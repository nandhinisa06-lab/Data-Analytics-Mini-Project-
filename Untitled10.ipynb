# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhinisa06-lab/Data-Analytics-Mini-Project-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# From Python Lists
arr = np.array([1, 2, 3])
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])

# Special Arrays
np.zeros((3, 3))
np.ones((2, 4))
np.eye(3)
np.arange(0, 10, 2)
np.linspace(0, 1, 5)
np.random.rand(3, 2)
np.random.randn(3, 2)
# Out:
# array([[ 0.55774927,  1.09183729],
#        [-0.95925024,  0.66118175],
#        [ 1.37869598,  0.91028387]])
